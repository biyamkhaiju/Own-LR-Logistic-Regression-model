# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

class LogisticRegression:
    def __init__(self, lr=0.1, epochs=1000):
        self.lr = lr
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for epoch in range(self.epochs):
            linear_model = np.dot(X, self.weights) + self.bias
            y_predicted = sigmoid(linear_model)

            dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1 / n_samples) * np.sum(y_predicted - y)

            self.weights -= self.lr * dw
            self.bias -= self.lr * db

            if epoch == 999:
                print(f"Epoch {epoch + 1}: Weight = {self.weights}, Bias = {self.bias}")

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = sigmoid(linear_model)
        return [1 if i > 0.5 else 0 for i in y_predicted]

X = np.array([[22, 25000], [25, 32000], [47, 70000], [52, 80000], [46, 65000], [56, 90000], [28, 40000]])
y = np.array([0, 0, 1, 1, 1, 1, 0])

model = LogisticRegression(lr=0.1, epochs=1000)
model.fit(X, y)

predictions = model.predict(X)
print("Predictions:", predictions)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='coolwarm', edgecolor='k')
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Purchase Decision Based on Age and Salary")
plt.legend(title='Purchase', labels=['No', 'Yes'])
plt.show()

ages = np.linspace(min(X[:, 0]), max(X[:, 0]), 100)
salaries = (-model.weights[0] * ages - model.bias) / model.weights[1]
plt.plot(ages, salaries, color='black', linestyle='dashed', label='Decision Boundary')
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='coolwarm', edgecolor='k')
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Logistic Regression Decision Boundary")
plt.legend(title='Purchase', labels=['No', 'Yes'])
plt.show()
# Out:
# <ipython-input-6-fe6f6e940014>:6: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))
# Epoch 1000: Weight = [-119.22857143 1185.71428571], Bias = -18.707142857142994
# Predictions: [1, 1, 1, 1, 1, 1, 1]

# %%
def fit(self, X, y):
    n_samples, n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for epoch in range(self.epochs):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = sigmoid(linear_model)

        dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
        db = (1 / n_samples) * np.sum(y_predicted - y)

        self.weights -= self.lr * dw
        self.bias -= self.lr * db

        # Print weights and bias at 1000th epoch
    if epoch == 999:  # 1000th epoch (0-indexed)
        print(f"Epoch {epoch + 1}: Weight = {self.weights}, Bias = {self.bias}")
